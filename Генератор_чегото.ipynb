# %% [markdown]
# <a href="https://colab.research.google.com/github/delloys/lab-1-/blob/master/%D0%93%D0%B5%D0%BD%D0%B5%D1%80%D0%B0%D1%82%D0%BE%D1%80_%D1%87%D0%B5%D0%B3%D0%BE%D1%82%D0%BE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Для работы загрузить 4 файла xlsx с названиями "excel2.xlsx",...,"excel5.xlsx", и поменять МН и Значение для МН

# %%
#ИБ1 Длина когтей в см
#arr = [[1,4,11,13,16,20],
#     [0.3,0.5,1.2,3.1,3.1,5.2]]

#ИБ2 Длина когтей в см
#arr = [[4,9,11,12,14,15,25],
#      [0.1,0.7,1.1,1.1,3.1,4.7,6.2]]   

#ИБ3 Длина когтей в см
arr = [[2,5,8,12,15,20,28],
       [0.3,0.5,0.5,1.2,2.0,6.0,6.0]]

#ИБ1 Длина уха
#arr = [[3,8,11,19,20,22,27],
#       [7.1,7.4,7.9,8.2,10.0,12.8,15.4]]

#ИБ2 Длина уха
#arr = [[19,21,23,24,30],
#       [7.9,8.9,12.1,12.8,15.3]]

#ИБ3 Длина уха
#arr = [[2,10,15,20,26,28],
#       [7.1,7.3,7.7,10.0,14.0,15.0]]

#ИБ4 Длина когтей в см
#arr = [[1,3,6,11,13,19,22],
#       [0.7,0.8,1.0,1.3,0.6,0.7,0.2]]

#ИБ5 Длина когтей в см 
#arr = [[5,7,8,9,11,13,17,21],
#       [0.5,1.0,1.1,1.1,1.2,1.4,0.1,0.6]]

#ИБ6 Длина когтей в см
#arr = [[6,8,10,12,14,19,22],
#       [0.8,1.0,1.1,1.4,0.2,0.6,0.9]]

#ИБ4 Длина уха
#arr = [[10,17,20,24,39,40],
#       [7.0,7.1,7.2,7.0,7.1,7.0]]

#ИБ5 Длина уха
#arr = [[15,20,23,26,30,37],
#       [7.1,7.7,7.5,7.0,7.0,7.0]]

#ИБ6 Длина уха
#arr = [[16,20,22,23,30,40],
#       [7.0,7.3,7.4,7.5,7.1,7.0]]

# %%
#@title
from traitlets.traitlets import observe_compat
import math
import openpyxl
import numpy as np
from openpyxl import Workbook
from openpyxl import load_workbook
from openpyxl.styles import Border, Side

def clear_shit(list_name):

    wb = openpyxl.load_workbook(filename=list_name)
    sheet = wb["Лист1"]
    sheet.delete_cols(0, 100)
    wb.save(list_name)

clear_shit("excel2.xlsx")
clear_shit("excel3.xlsx")
clear_shit("excel4.xlsx")
clear_shit("excel5.xlsx")

n1=[]
n2=[]
n3=[]
n4=[]
n5=[]
lb=[]
ub=[]
o=1
num_of_CHPD = 2

all_arr=[]

thins = Side(border_style="thin", color="000000")
double = Side(border_style="medium", color="000000")

for p1 in range(1,len(arr[0])):
                    for i in range (0,p1):
                         z="[" + str(arr[1][i]) + "]"
                         n1.append(z)
                    for i in range (p1,len(arr[0])):
                         z="[" + str(arr[1][i]) + "]"
                         n2.append(z)
                    n1temp = []
                    n2temp = []
                    for item in n1: 
                        if item not in n1temp: 
                            n1temp.append(item)
                    n1 = n1temp
                    for item in n2: 
                        if item not in n2temp: 
                            n2temp.append(item)
                    n2 = n2temp
                    for a in n1:
                         for b in n2:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []

                    full_data1 = 'v'.join(n1)
                    full_data2 = 'v'.join(n2)
                    columns = ['ЗДП', 'А', '№ Периода', 'НГ', 'ВГ']
                    rows = [
                        [full_data1],
                        [full_data2],
                    ]

                    wb = load_workbook("excel2.xlsx")
                    ws = wb.active

                    if len(n1)!=0 and len(n2)!=0:
                      if len(n1) > 1:
                        lb.append(str(arr[0][0]))
                        z1 = str(math.floor((arr[0][len(n1)-1] + arr[0][len(n1)])/2))
                        lb.append(z1)

                        z2 = str(arr[0][len(n1)]) + ' - ' + z1
                        ub.append(z2)
                        z3 = str(arr[0][-1]) + ' - ' + z1
                        ub.append(z3)
                      else:
                        lb.append(str(arr[0][0]))
                        z1 = str(arr[0][len(n1)-1])
                        lb.append(z1)

                        z2 = str(arr[0][len(n1)]) + ' - ' + z1
                        ub.append(z2)
                        z3 = str(arr[0][len(n2)]) + ' - ' + z1
                        ub.append(z3)

                      all_arr = np.array([lb,ub])
                      all_arr = all_arr.reshape(all_arr.size)
                      print(all_arr,'alaalllr')

                      for i, value in enumerate(columns, 1):
                        ws.cell(row=1, column=i).value = value

                      for i, row in enumerate(rows, o*num_of_CHPD):
                        for j, value in enumerate(row, 1):
                            cell = ws.cell(row=i, column=j)
                            cell.value = value
                             
                            if i % num_of_CHPD != 0:
                              ws['D'+str(o*num_of_CHPD)].value = all_arr[0]
                              ws['D'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD)].value = all_arr[1]
                              ws['E'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD)].value = 1
                              ws['C'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=double, left=thins, right=thins)
                            else:
                              ws['D'+str(o*num_of_CHPD + 1)].value = all_arr[2]
                              ws['D'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 1)].value = all_arr[3]
                              ws['E'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 1)].value = 2
                              ws['C'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=thins, left=thins, right=thins)

                      ws.merge_cells('B'+str(o*num_of_CHPD)+':B' + str((o*num_of_CHPD)+1))

                      ws['B'+str(o*num_of_CHPD)].value = str(num_of_CHPD) +'.' + str(o)
                      ws['B'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=double, left=thins, right=thins)

                      wb.save('excel2.xlsx')
                      o+=1
                      lb=[]
                      ub = []
                      n1 = []
                      n2 = []
                      n3 = []
                      n4 = []
                      n5 = []
                      all_arr = []

o=1
num_of_CHPD = 3
for p1 in range(1,len(arr[0])):
     for p2 in range(p1+1, len(arr[0])):
                    for i in range (0,p1):
                         z="[" + str(arr[1][i]) + "]"
                         n1.append(z)
                    for i in range (p1,p2):
                         z="[" + str(arr[1][i]) + "]"
                         n2.append(z)
                    for i in range(p2, len(arr[0])):
                         z="[" + str(arr[1][i]) + "]"
                         n3.append(z)
                    n1temp = []
                    n2temp = []
                    n3temp = []
                    for item in n1: 
                        if item not in n1temp: 
                            n1temp.append(item)
                    n1 = n1temp
                    for item in n2: 
                        if item not in n2temp: 
                            n2temp.append(item)
                    n2 = n2temp
                    for item in n3: 
                        if item not in n3temp: 
                            n3temp.append(item)
                    n3 = n3temp
                    for a in n1:
                         for b in n2:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n2:
                         for b in n3:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []

                    full_data1 = 'v'.join(n1)
                    full_data2 = 'v'.join(n2)
                    full_data3 = 'v'.join(n3)
                    columns = ['ЗДП', 'А', '№ Периода', 'НГ', 'ВГ']
                    rows = [
                        [full_data1],
                        [full_data2],
                        [full_data3]
                    ]

                    wb = load_workbook("excel3.xlsx")
                    ws = wb.active
                    
                    if len(n1) != 0 and len(n2) != 0 and len(n3) != 0:
                      if len(n1) > 1:
                         lb.append(str(arr[0][0]))
                         z0 = str(math.floor((arr[0][len(n1)-1] + arr[0][len(n1)])/2))
                         lb.append(z0)
                      else:
                         lb.append(str(arr[0][0]))
                         z0 = (str(arr[0][len(n1)-1]))
                         lb.append(z0)
                      if len(n2) > 1:
                         z1 = str(arr[0][len(n1)]) + ' - ' + z0
                         lb.append(z1)
                         z2 = str(math.floor((arr[0][len(n1)] + arr[0][len(n1) + len(n2) - 1])/2))
                         z2_1 = z2  + ' - ' + z0
                         lb.append(z2_1)
                         z3 = str(arr[0][len(n1) + len(n2)]) + ' - ' + z2
                         lb.append(z3)
                         z4 = str(arr[0][-1]) + ' - ' + z2
                         lb.append(z4)
                      else:
                         z1 = str(arr[0][len(n1)]) + ' - ' + z0
                         lb.append(z1)
                         z2 = str(arr[0][len(n1) + len(n2) - 1])
                         z2_1 = z2  + ' - ' + z0
                         lb.append(z2_1)
                         z3 = str(arr[0][len(n1) + len(n2)]) + ' - ' + z2
                         lb.append(z3)
                         z4 = str(arr[0][-1]) + ' - ' + z2
                         lb.append(z4)

                      for i, row in enumerate(rows, o*num_of_CHPD):
                        for j, value in enumerate(row, 1):
                            cell = ws.cell(row=i, column=j)
                            cell.value = value
                        if i % num_of_CHPD != 1:
                              ws['D'+str(o*num_of_CHPD)].value = lb[0]
                              ws['D'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD)].value = lb[1]
                              ws['E'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 1)].value = lb[2]
                              ws['D'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 1)].value = lb[3]
                              ws['E'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD)].value = 1
                              ws['C'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 1)].value = 2
                              ws['C'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=double, left=thins, right=thins)
                        else:
                              ws['D'+str(o*num_of_CHPD + 2)].value = lb[4]
                              ws['D'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 2)].value = lb[5]
                              ws['E'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 2)].value = 3
                              ws['C'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=thins, left=thins, right=thins)

                      ws.merge_cells('B'+str(o*num_of_CHPD)+':B' + str((o*num_of_CHPD)+2))
                      ws['B'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                      ws['B'+str(o*num_of_CHPD)].value = str(num_of_CHPD) +'.' + str(o)
                      o+=1
                      wb.save('excel3.xlsx')
                      
                      lb=[]
                      ub = []
                      n1 = []
                      n2 = []
                      n3 = []
                      n4 = []
                      n5 = [] 

o=1
num_of_CHPD = 4
for p1 in range(1,len(arr[0])):
     for p2 in range(p1+1, len(arr[0])):
          for p3 in range(p2 + 1, len(arr[0])):
                    for i in range (0,p1):
                         z="[" + str(arr[1][i]) + "]"
                         n1.append(z)
                    for i in range (p1,p2):
                         z="[" + str(arr[1][i]) + "]"
                         n2.append(z)
                    for i in range(p2, p3):
                         z="[" + str(arr[1][i]) + "]"
                         n3.append(z)
                    for i in range(p3,len(arr[0])):
                         z="[" + str(arr[1][i]) + "]"
                         n4.append(z)
                    n1temp = []
                    n2temp = []
                    n3temp = []
                    n4temp = []
                    for item in n1: 
                        if item not in n1temp: 
                            n1temp.append(item)
                    n1 = n1temp
                    for item in n2: 
                        if item not in n2temp: 
                            n2temp.append(item)
                    n2 = n2temp
                    for item in n3: 
                        if item not in n3temp: 
                            n3temp.append(item)
                    n3 = n3temp
                    for item in n4: 
                        if item not in n4temp: 
                            n4temp.append(item)
                    n4 = n4temp
                    for a in n1:
                         for b in n2:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n2:
                         for b in n3:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n3:
                         for b in n4:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    full_data1 = 'v'.join(n1)
                    full_data2 = 'v'.join(n2)
                    full_data3 = 'v'.join(n3)
                    full_data4 = 'v'.join(n4)
                    columns = ['ЗДП', 'А', '№ Периода', 'НГ', 'ВГ']
                    rows = [
                        [full_data1],
                        [full_data2],
                        [full_data3],
                        [full_data4]
                    ]

                    wb = load_workbook("excel4.xlsx")
                    ws = wb.active

                    if len(n1)!=0 and len(n4)!=0 and len(n3)!=0 and len(n2)!=0:
                      if len(n1) > 1:
                        lb.append(str(arr[0][0]))
                        z0 = str(math.floor((arr[0][len(n1)-1] + arr[0][len(n1)])/2))
                        lb.append(z0)
                      else:  
                        lb.append(str(arr[0][0]))
                        z0 = str(arr[0][len(n1) - 1])
                        lb.append(z0)
                      if len(n2) > 1:
                        z1 = str(arr[0][len(n1)])
                        z1_1 = z1  + ' - ' + z0
                        lb.append(z1_1)
                        z2 = str(math.floor((arr[0][len(n1) - 1] + arr[0][len(n1) + len(n2)])/2))
                        z2_1 = z2  + ' - ' + z0
                        lb.append(z2_1)
                      else:
                        z1 = str(arr[0][len(n1)])
                        z1_1 = z1  + ' - ' + z0
                        lb.append(z1_1)
                        z2 = str(arr[0][len(n1) + len(n2) -1])
                        z2_1 = z2  + ' - ' + z0
                        lb.append(z2_1)
                      if len(n3) > 1:
                        z3 = str(arr[0][len(n1) + len(n2)])
                        z3_1 = z3  + ' - ' + z2
                        lb.append(z3_1)
                        z4 = str(math.floor((arr[0][len(n1) + len(n2) + len(n3) - 1] + arr[0][len(n1) + len(n2) + len(n3)])/2))
                        z4_1 = z4 + ' - ' + z2
                        lb.append(z4_1)
                      else:
                        z3 = str(arr[0][len(n1) + len(n2)])
                        z3_1 = z3  + ' - ' + z2
                        lb.append(z3_1)
                        z4 = str(arr[0][len(n1) + len(n2) + len(n3) - 1])
                        z4_1 = z4 + ' - ' + z2
                        lb.append(z4_1)

                      z5 = str(arr[0][len(n1) + len(n2) + len(n3)]) + ' - ' + z4
                      lb.append(z5)
                      z6 = str(arr[0][-1]) + ' - ' + z4
                      lb.append(z6)
                    
                      for i, row in enumerate(rows, o*num_of_CHPD):
                        for j, value in enumerate(row, 1):
                            cell = ws.cell(row=i, column=j)
                            cell.value = value
                        if i % num_of_CHPD != 3:
                              ws['D'+str(o*num_of_CHPD)].value = lb[0]
                              ws['D'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD)].value = lb[1]
                              ws['E'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 1)].value = lb[2]
                              ws['D'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 1)].value = lb[3]
                              ws['E'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 2)].value = lb[4]
                              ws['D'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 2)].value = lb[5]
                              ws['E'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD)].value = 1
                              ws['C'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 1)].value = 2
                              ws['C'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 2)].value = 3
                              ws['C'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=thins, left=thins, right=thins)
                        else:
                              ws['D'+str(o*num_of_CHPD + 3)].value = lb[6]
                              ws['D'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 3)].value = lb[7]
                              ws['E'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 3)].value = 4
                              ws['C'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=double, left=thins, right=thins)

                      ws.merge_cells('B'+str(o*num_of_CHPD)+':B' + str((o*num_of_CHPD)+3))
                      ws['B'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                      ws['B'+str(o*num_of_CHPD)].value = str(num_of_CHPD) +'.' + str(o)
                      wb.save('excel4.xlsx')

                      o+=1
                      lb=[]
                      ub = []
                      n1 = []
                      n2 = []
                      n3 = []
                      n4 = []
                      n5 = []

o = 1
num_of_CHPD = 5
for p1 in range(1,len(arr[0])):
     for p2 in range(p1+1, len(arr[0])):
          for p3 in range(p2 + 1, len(arr[0])):
               for p4 in range(p3 + 1, len(arr[0])):
                    for i in range (0,p1):
                         z="[" + str(arr[1][i]) + "]"
                         n1.append(z)
                    for i in range (p1,p2):
                         z="[" + str(arr[1][i]) + "]"
                         n2.append(z)
                    for i in range(p2, p3):
                         z="[" + str(arr[1][i]) + "]"
                         n3.append(z)
                    for i in range(p3,p4):
                         z="[" + str(arr[1][i]) + "]"
                         n4.append(z)
                    for i in range(p4, len(arr[0])):
                         z="[" + str(arr[1][i]) + "]"
                         n5.append(z)
                    n1temp = []
                    n2temp = []
                    n3temp = []
                    n4temp = []
                    n5temp = []
                    for item in n1: 
                        if item not in n1temp: 
                            n1temp.append(item)
                    n1 = n1temp
                    for item in n2: 
                        if item not in n2temp: 
                            n2temp.append(item)
                    n2 = n2temp
                    for item in n3: 
                        if item not in n3temp: 
                            n3temp.append(item)
                    n3 = n3temp
                    for item in n4: 
                        if item not in n4temp: 
                            n4temp.append(item)
                    n4 = n4temp
                    for item in n5: 
                        if item not in n5temp: 
                            n5temp.append(item)
                    n5 = n5temp
                    for a in n1:
                         for b in n2:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n2:
                         for b in n3:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n3:
                         for b in n4:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n4:
                         for b in n5:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    full_data1 = 'v'.join(n1)
                    full_data2 = 'v'.join(n2)
                    full_data3 = 'v'.join(n3)
                    full_data4 = 'v'.join(n4)
                    full_data5 = 'v'.join(n5)
                    columns = ['ЗДП', 'А', '№ Периода', 'НГ', 'ВГ']
                    rows = [
                        [full_data1],
                        [full_data2],
                        [full_data3],
                        [full_data4],
                        [full_data5]
                    ]

                    wb = load_workbook("excel5.xlsx")
                    ws = wb.active

                    if len(n1)!=0 and len(n5)!=0 and len(n4)!=0 and len(n3)!=0 and len(n2)!=0:
                      if len(n1) > 1:
                        lb.append(str(arr[0][0]))
                        z0 = str(math.floor((arr[0][len(n1)-1] + arr[0][len(n1)])/2))
                        lb.append(z0)
                      else:
                        lb.append(str(arr[0][0]))
                        z0 = str(arr[0][len(n1)-1])
                        lb.append(z0)
                      if len(n2) > 1:
                        z1 = str(arr[0][len(n1)])
                        z1_1 = z1  + ' - ' + z0
                        lb.append(z1_1)
                        z2 = str(math.floor((arr[0][len(n2)] + arr[0][len(n1) + len(n2)])/2))
                        z2_1 = z2  + ' - ' + z0
                        lb.append(z2_1)
                      else:
                        z1 = str(arr[0][len(n1)])
                        z1_1 = z1  + ' - ' + z0
                        lb.append(z1_1)
                        z2 = str(arr[0][len(n1) + len(n2) - 1])
                        z2_1 = z2  + ' - ' + z0
                        lb.append(z2_1)
                      if len(n3) > 1:
                        z3 = str(arr[0][len(n1) + len(n2)])
                        z3_1 = z3  + ' - ' + z2
                        lb.append(z3_1)
                        z4 = str(math.floor((arr[0][len(n1) + len(n2) + len(n3) - 1] + arr[0][len(n1) + len(n2) + len(n3)])/2))
                        z4_1 = z4 + ' - ' + z2
                        lb.append(z4_1)
                      else:
                        z3 = str(arr[0][len(n1) + len(n2)])
                        z3_1 = z3  + ' - ' + z2
                        lb.append(z3_1)
                        z4 = str(arr[0][len(n1) + len(n2) + len(n3) - 1])
                        z4_1 = z4 + ' - ' + z2
                        lb.append(z4_1)
                      if len(n4) > 1:
                        z5 = str(arr[0][len(n1) + len(n2) + len(n3) ])
                        z5_1 = z5 + ' - ' + z4
                        lb.append(z5_1)
                        z6 = str(math.floor((arr[0][len(n1) + len(n2) + len(n3) + len(n4)-1] + arr[0][len(n1) + len(n2) + len(n3) + len(n4)])/2))
                        z6_1 = z6 + ' - ' + z4
                        lb.append(z6_1)
                      else:
                        z5 = str(arr[0][len(n1) + len(n2) + len(n3) ])
                        z5_1 = z5 + ' - ' + z4
                        lb.append(z5_1)
                        z6 = str(arr[0][len(n1) + len(n2) + len(n3) + len(n4)-1])
                        z6_1 = z6 + ' - ' + z4
                        lb.append(z6_1)

                      z7 = str(arr[0][len(n1) + len(n2) + len(n3) + len(n4)])
                      z7_1 = z7 + ' - ' + z6
                      lb.append(z7_1)
                      z8 = str(arr[0][-1])
                      z8_1 = z8 + ' - ' + z6
                      lb.append(z8_1)

                      for i, row in enumerate(rows, o*num_of_CHPD):
                        for j, value in enumerate(row, 1):
                            cell = ws.cell(row=i, column=j)
                            cell.value = value
                        if i % num_of_CHPD != 4:
                              ws['D'+str(o*num_of_CHPD)].value = lb[0]
                              ws['D'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD)].value = lb[1]
                              ws['E'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 1)].value = lb[2]
                              ws['D'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 1)].value = lb[3]
                              ws['E'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 2)].value = lb[4]
                              ws['D'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 2)].value = lb[5]
                              ws['E'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 3)].value = lb[6]
                              ws['D'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 3)].value = lb[7]
                              ws['E'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD)].value = 1
                              ws['C'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 1)].value = 2
                              ws['C'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 2)].value = 3
                              ws['C'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 3)].value = 4
                              ws['C'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=thins, left=thins, right=thins)
                        else:
                              ws['D'+str(o*num_of_CHPD + 4)].value = lb[8]
                              ws['D'+str(o*num_of_CHPD + 4)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 4)].value = lb[9]
                              ws['E'+str(o*num_of_CHPD + 4)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 4)].value = 5
                              ws['C'+str(o*num_of_CHPD + 4)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=double, left=thins, right=thins)

                      ws.merge_cells('B'+str(o*num_of_CHPD)+':B' + str((o*num_of_CHPD)+4))
                      ws['B'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                      ws['B'+str(o*num_of_CHPD)].value = str(num_of_CHPD) +'.' + str(o)
                      wb.save('excel5.xlsx')
                      o+=1
                      lb=[]
                      ub = []
                      n1 = []
                      n2 = []
                      n3 = []
                      n4 = []
                      n5 = []
# Out:
# ['2' '2' '5 - 2' '15 - 2'] alaalllr
# ['2' '6' '8 - 6' '28 - 6'] alaalllr
# ['2' '10' '12 - 10' '28 - 10'] alaalllr
# ['2' '13' '15 - 13' '28 - 13'] alaalllr

# %%
from traitlets.traitlets import observe_compat
import math
import openpyxl
import numpy as np
from openpyxl import Workbook
from openpyxl import load_workbook
from openpyxl.styles import Border, Side

def clear_shit(list_name):

    wb = openpyxl.load_workbook(filename=list_name)
    sheet = wb["Лист1"]
    sheet.delete_cols(0, 100)
    wb.save(list_name)

clear_shit("excel2.xlsx")
clear_shit("excel3.xlsx")
clear_shit("excel4.xlsx")
clear_shit("excel5.xlsx")

n1=[]
n2=[]
n3=[]
n4=[]
n5=[]
lb=[]
ub=[]
o=1
num_of_CHPD = 2

all_arr=[]

thins = Side(border_style="thin", color="000000")
double = Side(border_style="medium", color="000000")

for p1 in range(1,len(arr[0])):
                    for i in range (0,p1):
                         z="[" + str(arr[1][i]) + "]"
                         n1.append(z)
                    for i in range (p1,len(arr[0])):
                         z="[" + str(arr[1][i]) + "]"
                         n2.append(z)
                    for a in n1:
                         for b in n2:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []

                    full_data1 = 'v'.join(n1)
                    full_data2 = 'v'.join(n2)
                    columns = ['ЗДП', 'А', '№ Периода', 'НГ', 'ВГ']
                    rows = [
                        [full_data1],
                        [full_data2],
                    ]

                    wb = load_workbook("excel2.xlsx")
                    ws = wb.active

                    if len(n1)!=0 and len(n2)!=0:
                      if len(n1) > 1:
                        lb.append(str(arr[0][0]))
                        z1 = str(math.floor((arr[0][len(n1)-1] + arr[0][len(n1)])/2))
                        lb.append(z1)

                        z2 = str(arr[0][len(n1)]) + ' - ' + z1
                        ub.append(z2)
                        z3 = str(arr[0][-1]) + ' - ' + z1
                        ub.append(z3)
                      else:
                        lb.append(str(arr[0][0]))
                        z1 = str(arr[0][len(n1)-1])
                        lb.append(z1)

                        z2 = str(arr[0][len(n1)]) + ' - ' + z1
                        ub.append(z2)
                        z3 = str(arr[0][len(n2)]) + ' - ' + z1
                        ub.append(z3)

                      all_arr = np.array([lb,ub])
                      all_arr = all_arr.reshape(all_arr.size)
                      print(all_arr,'alaalllr')

                    for i, value in enumerate(columns, 1):
                        ws.cell(row=1, column=i).value = value

                    for i, row in enumerate(rows, o*num_of_CHPD):
                        for j, value in enumerate(row, 1):
                            cell = ws.cell(row=i, column=j)
                            cell.value = value
                             
                            if i % num_of_CHPD != 0:
                              ws['D'+str(o*num_of_CHPD)].value = all_arr[0]
                              ws['D'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD)].value = all_arr[1]
                              ws['E'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD)].value = 1
                              ws['C'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=double, left=thins, right=thins)
                            else:
                              ws['D'+str(o*num_of_CHPD + 1)].value = all_arr[2]
                              ws['D'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 1)].value = all_arr[3]
                              ws['E'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 1)].value = 2
                              ws['C'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=thins, left=thins, right=thins)

                    ws.merge_cells('B'+str(o*num_of_CHPD)+':B' + str((o*num_of_CHPD)+1))

                    ws['B'+str(o*num_of_CHPD)].value = str(num_of_CHPD) +'.' + str(o)
                    ws['B'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=double, left=thins, right=thins)

                    wb.save('excel2.xlsx')
                    o+=1
                    lb=[]
                    ub = []
                    n1 = []
                    n2 = []
                    n3 = []
                    n4 = []
                    n5 = []
                    all_arr = []

  
o=1
num_of_CHPD = 3
for p1 in range(1,len(arr[0])):
     for p2 in range(p1+1, len(arr[0])):
                    for i in range (0,p1):
                         z="[" + str(arr[1][i]) + "]"
                         n1.append(z)
                    for i in range (p1,p2):
                         z="[" + str(arr[1][i]) + "]"
                         n2.append(z)
                    for i in range(p2, len(arr[0])):
                         z="[" + str(arr[1][i]) + "]"
                         n3.append(z)
                    for a in n1:
                         for b in n2:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n2:
                         for b in n3:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []

                    full_data1 = 'v'.join(n1)
                    full_data2 = 'v'.join(n2)
                    full_data3 = 'v'.join(n3)
                    columns = ['ЗДП', 'А', '№ Периода', 'НГ', 'ВГ']
                    rows = [
                        [full_data1],
                        [full_data2],
                        [full_data3]
                    ]

                    wb = load_workbook("excel3.xlsx")
                    ws = wb.active
                    
                    if len(n1) != 0 and len(n2) != 0 and len(n3) != 0:
                      if len(n1) > 1:
                         lb.append(str(arr[0][0]))
                         z0 = str(math.floor((arr[0][len(n1)-1] + arr[0][len(n1)])/2))
                         lb.append(z0)
                      else:
                         lb.append(str(arr[0][0]))
                         z0 = (str(arr[0][len(n1)-1]))
                         lb.append(z0)
                      if len(n2) > 1:
                         z1 = str(arr[0][len(n1)]) + ' - ' + z0
                         lb.append(z1)
                         z2 = str(math.floor((arr[0][len(n1)] + arr[0][len(n1) + len(n2) - 1])/2))
                         z2_1 = z2  + ' - ' + z0
                         lb.append(z2_1)
                         z3 = str(arr[0][len(n1) + len(n2)]) + ' - ' + z2
                         lb.append(z3)
                         z4 = str(arr[0][-1]) + ' - ' + z2
                         lb.append(z4)
                      else:
                         z1 = str(arr[0][len(n1)]) + ' - ' + z0
                         lb.append(z1)
                         z2 = str(arr[0][len(n1) + len(n2) - 1])
                         z2_1 = z2  + ' - ' + z0
                         lb.append(z2_1)
                         z3 = str(arr[0][len(n1) + len(n2)]) + ' - ' + z2
                         lb.append(z3)
                         z4 = str(arr[0][-1]) + ' - ' + z2
                         lb.append(z4)

                    for i, row in enumerate(rows, o*num_of_CHPD):
                        for j, value in enumerate(row, 1):
                            cell = ws.cell(row=i, column=j)
                            cell.value = value
                        if i % num_of_CHPD != 1:
                              ws['D'+str(o*num_of_CHPD)].value = lb[0]
                              ws['D'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD)].value = lb[1]
                              ws['E'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 1)].value = lb[2]
                              ws['D'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 1)].value = lb[3]
                              ws['E'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD)].value = 1
                              ws['C'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 1)].value = 2
                              ws['C'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=double, left=thins, right=thins)
                        else:
                              ws['D'+str(o*num_of_CHPD + 2)].value = lb[4]
                              ws['D'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 2)].value = lb[5]
                              ws['E'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 2)].value = 3
                              ws['C'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=thins, left=thins, right=thins)
                    

                    ws.merge_cells('B'+str(o*num_of_CHPD)+':B' + str((o*num_of_CHPD)+2))
                    ws['B'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                    ws['B'+str(o*num_of_CHPD)].value = str(num_of_CHPD) +'.' + str(o)
                    o+=1
                    wb.save('excel3.xlsx')
                    
                    lb=[]
                    ub = []
                    n1 = []
                    n2 = []
                    n3 = []
                    n4 = []
                    n5 = []    


o=1
num_of_CHPD = 4
for p1 in range(1,len(arr[0])):
     for p2 in range(p1+1, len(arr[0])):
          for p3 in range(p2 + 1, len(arr[0])):
                    for i in range (0,p1):
                         z="[" + str(arr[1][i]) + "]"
                         n1.append(z)
                    for i in range (p1,p2):
                         z="[" + str(arr[1][i]) + "]"
                         n2.append(z)
                    for i in range(p2, p3):
                         z="[" + str(arr[1][i]) + "]"
                         n3.append(z)
                    for i in range(p3,len(arr[0])):
                         z="[" + str(arr[1][i]) + "]"
                         n4.append(z)
                    for a in n1:
                         for b in n2:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n2:
                         for b in n3:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n3:
                         for b in n4:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    full_data1 = 'v'.join(n1)
                    full_data2 = 'v'.join(n2)
                    full_data3 = 'v'.join(n3)
                    full_data4 = 'v'.join(n4)
                    columns = ['ЗДП', 'А', '№ Периода', 'НГ', 'ВГ']
                    rows = [
                        [full_data1],
                        [full_data2],
                        [full_data3],
                        [full_data4]
                    ]

                    wb = load_workbook("excel4.xlsx")
                    ws = wb.active

                    if len(n1)!=0 and len(n4)!=0 and len(n3)!=0 and len(n2)!=0:
                      if len(n1) > 1:
                        lb.append(str(arr[0][0]))
                        z0 = str(math.floor((arr[0][len(n1)-1] + arr[0][len(n1)])/2))
                        lb.append(z0)
                      else:  
                        lb.append(str(arr[0][0]))
                        z0 = str(arr[0][len(n1) - 1])
                        lb.append(z0)
                      if len(n2) > 1:
                        z1 = str(arr[0][len(n1)])
                        z1_1 = z1  + ' - ' + z0
                        lb.append(z1_1)
                        z2 = str(math.floor((arr[0][len(n1) - 1] + arr[0][len(n1) + len(n2)])/2))
                        z2_1 = z2  + ' - ' + z0
                        lb.append(z2_1)
                      else:
                        z1 = str(arr[0][len(n1)])
                        z1_1 = z1  + ' - ' + z0
                        lb.append(z1_1)
                        z2 = str(arr[0][len(n1) + len(n2) -1])
                        z2_1 = z2  + ' - ' + z0
                        lb.append(z2_1)
                      if len(n3) > 1:
                        z3 = str(arr[0][len(n1) + len(n2)])
                        z3_1 = z3  + ' - ' + z2
                        lb.append(z3_1)
                        z4 = str(math.floor((arr[0][len(n1) + len(n2) + len(n3) - 1] + arr[0][len(n1) + len(n2) + len(n3)])/2))
                        z4_1 = z4 + ' - ' + z2
                        lb.append(z4_1)
                      else:
                        z3 = str(arr[0][len(n1) + len(n2)])
                        z3_1 = z3  + ' - ' + z2
                        lb.append(z3_1)
                        z4 = str(arr[0][len(n1) + len(n2) + len(n3) - 1])
                        z4_1 = z4 + ' - ' + z2
                        lb.append(z4_1)

                      z5 = str(arr[0][len(n1) + len(n2) + len(n3)]) + ' - ' + z4
                      lb.append(z5)
                      z6 = str(arr[0][-1]) + ' - ' + z4
                      lb.append(z6)
                    
                    for i, row in enumerate(rows, o*num_of_CHPD):
                        for j, value in enumerate(row, 1):
                            cell = ws.cell(row=i, column=j)
                            cell.value = value
                        if i % num_of_CHPD != 3:
                              ws['D'+str(o*num_of_CHPD)].value = lb[0]
                              ws['D'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD)].value = lb[1]
                              ws['E'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 1)].value = lb[2]
                              ws['D'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 1)].value = lb[3]
                              ws['E'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 2)].value = lb[4]
                              ws['D'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 2)].value = lb[5]
                              ws['E'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD)].value = 1
                              ws['C'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 1)].value = 2
                              ws['C'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 2)].value = 3
                              ws['C'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=thins, left=thins, right=thins)
                        else:
                              ws['D'+str(o*num_of_CHPD + 3)].value = lb[6]
                              ws['D'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 3)].value = lb[7]
                              ws['E'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 3)].value = 4
                              ws['C'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=double, left=thins, right=thins)

                    ws.merge_cells('B'+str(o*num_of_CHPD)+':B' + str((o*num_of_CHPD)+3))
                    ws['B'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                    ws['B'+str(o*num_of_CHPD)].value = str(num_of_CHPD) +'.' + str(o)
                    wb.save('excel4.xlsx')

                    o+=1
                    lb=[]
                    ub = []
                    n1 = []
                    n2 = []
                    n3 = []
                    n4 = []
                    n5 = []      


o = 1
num_of_CHPD = 5
for p1 in range(1,len(arr[0])):
     for p2 in range(p1+1, len(arr[0])):
          for p3 in range(p2 + 1, len(arr[0])):
               for p4 in range(p3 + 1, len(arr[0])):
                    for i in range (0,p1):
                         z="[" + str(arr[1][i]) + "]"
                         n1.append(z)
                    for i in range (p1,p2):
                         z="[" + str(arr[1][i]) + "]"
                         n2.append(z)
                    for i in range(p2, p3):
                         z="[" + str(arr[1][i]) + "]"
                         n3.append(z)
                    for i in range(p3,p4):
                         z="[" + str(arr[1][i]) + "]"
                         n4.append(z)
                    for i in range(p4, len(arr[0])):
                         z="[" + str(arr[1][i]) + "]"
                         n5.append(z)
                    for a in n1:
                         for b in n2:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n2:
                         for b in n3:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n3:
                         for b in n4:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n4:
                         for b in n5:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    full_data1 = 'v'.join(n1)
                    full_data2 = 'v'.join(n2)
                    full_data3 = 'v'.join(n3)
                    full_data4 = 'v'.join(n4)
                    full_data5 = 'v'.join(n5)
                    columns = ['ЗДП', 'А', '№ Периода', 'НГ', 'ВГ']
                    rows = [
                        [full_data1],
                        [full_data2],
                        [full_data3],
                        [full_data4],
                        [full_data5]
                    ]

                    wb = load_workbook("excel5.xlsx")
                    ws = wb.active

                    if len(n1)!=0 and len(n5)!=0 and len(n4)!=0 and len(n3)!=0 and len(n2)!=0:
                      if len(n1) > 1:
                        lb.append(str(arr[0][0]))
                        z0 = str(math.floor((arr[0][len(n1)-1] + arr[0][len(n1)])/2))
                        lb.append(z0)
                      else:
                        lb.append(str(arr[0][0]))
                        z0 = str(arr[0][len(n1)-1])
                        lb.append(z0)
                      if len(n2) > 1:
                        z1 = str(arr[0][len(n1)])
                        z1_1 = z1  + ' - ' + z0
                        lb.append(z1_1)
                        z2 = str(math.floor((arr[0][len(n2)] + arr[0][len(n1) + len(n2)])/2))
                        z2_1 = z2  + ' - ' + z0
                        lb.append(z2_1)
                      else:
                        z1 = str(arr[0][len(n1)])
                        z1_1 = z1  + ' - ' + z0
                        lb.append(z1_1)
                        z2 = str(arr[0][len(n1) + len(n2) - 1])
                        z2_1 = z2  + ' - ' + z0
                        lb.append(z2_1)
                      if len(n3) > 1:
                        z3 = str(arr[0][len(n1) + len(n2)])
                        z3_1 = z3  + ' - ' + z2
                        lb.append(z3_1)
                        z4 = str(math.floor((arr[0][len(n1) + len(n2) + len(n3) - 1] + arr[0][len(n1) + len(n2) + len(n3)])/2))
                        z4_1 = z4 + ' - ' + z2
                        lb.append(z4_1)
                      else:
                        z3 = str(arr[0][len(n1) + len(n2)])
                        z3_1 = z3  + ' - ' + z2
                        lb.append(z3_1)
                        z4 = str(arr[0][len(n1) + len(n2) + len(n3) - 1])
                        z4_1 = z4 + ' - ' + z2
                        lb.append(z4_1)
                      if len(n4) > 1:
                        z5 = str(arr[0][len(n1) + len(n2) + len(n3) ])
                        z5_1 = z5 + ' - ' + z4
                        lb.append(z5_1)
                        z6 = str(math.floor((arr[0][len(n1) + len(n2) + len(n3) + len(n4)-1] + arr[0][len(n1) + len(n2) + len(n3) + len(n4)])/2))
                        z6_1 = z6 + ' - ' + z4
                        lb.append(z6_1)
                      else:
                        z5 = str(arr[0][len(n1) + len(n2) + len(n3) ])
                        z5_1 = z5 + ' - ' + z4
                        lb.append(z5_1)
                        z6 = str(arr[0][len(n1) + len(n2) + len(n3) + len(n4)-1])
                        z6_1 = z6 + ' - ' + z4
                        lb.append(z6_1)

                      z7 = str(arr[0][len(n1) + len(n2) + len(n3) + len(n4)])
                      z7_1 = z7 + ' - ' + z6
                      lb.append(z7_1)
                      z8 = str(arr[0][-1])
                      z8_1 = z8 + ' - ' + z6
                      lb.append(z8_1)

                      for i, row in enumerate(rows, o*num_of_CHPD):
                        for j, value in enumerate(row, 1):
                            cell = ws.cell(row=i, column=j)
                            cell.value = value
                        if i % num_of_CHPD != 4:
                              ws['D'+str(o*num_of_CHPD)].value = lb[0]
                              ws['D'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD)].value = lb[1]
                              ws['E'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 1)].value = lb[2]
                              ws['D'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 1)].value = lb[3]
                              ws['E'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 2)].value = lb[4]
                              ws['D'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 2)].value = lb[5]
                              ws['E'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 3)].value = lb[6]
                              ws['D'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 3)].value = lb[7]
                              ws['E'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD)].value = 1
                              ws['C'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 1)].value = 2
                              ws['C'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 2)].value = 3
                              ws['C'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 3)].value = 4
                              ws['C'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=thins, left=thins, right=thins)
                        else:
                              ws['D'+str(o*num_of_CHPD + 4)].value = lb[8]
                              ws['D'+str(o*num_of_CHPD + 4)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 4)].value = lb[9]
                              ws['E'+str(o*num_of_CHPD + 4)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 4)].value = 5
                              ws['C'+str(o*num_of_CHPD + 4)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=double, left=thins, right=thins)

                    ws.merge_cells('B'+str(o*num_of_CHPD)+':B' + str((o*num_of_CHPD)+4))
                    ws['B'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                    ws['B'+str(o*num_of_CHPD)].value = str(num_of_CHPD) +'.' + str(o)
                    wb.save('excel5.xlsx')
                    o+=1
                    lb=[]
                    ub = []
                    n1 = []
                    n2 = []
                    n3 = []
                    n4 = []
                    n5 = []
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-f26516bedb71> in <cell line: 36>()
#     102                               cell.border = Border(top=thins, bottom=double, left=thins, right=thins)
#     103                             else:
# --> 104                               ws['D'+str(o*num_of_CHPD + 1)].value = all_arr[2]
#     105                               ws['D'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=double, left=thins, right=thins)
#     106                               ws['E'+str(o*num_of_CHPD + 1)].value = all_arr[3]
#
# IndexError: list index out of range

# %%
wz = openpyxl.Workbook("excel1.xlsx")

wz.save('excel1.xlsx')

# %%
o=1
num_of_CHPD = 3
for p1 in range(1,len(arr[0])):
     for p2 in range(p1+1, len(arr[0])):
                    print('========')
                    for i in range (0,p1):
                         z="[" + str(arr[1][i]) + "]"
                         n1.append(z)
                    for i in range (p1,p2):
                         z="[" + str(arr[1][i]) + "]"
                         n2.append(z)
                    for i in range(p2, len(arr[0])):
                         z="[" + str(arr[1][i]) + "]"
                         n3.append(z)
                    for a in n1:
                         for b in n2:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n2:
                         for b in n3:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []

                    print("3.",o)
                    full_data1 = 'v'.join(n1)
                    full_data2 = 'v'.join(n2)
                    full_data3 = 'v'.join(n3)
                    columns = ['ЗДП', 'А', '№ Периода', 'НГ', 'ВГ']
                    rows = [
                        [full_data1],
                        [full_data2],
                        [full_data3]
                    ]

                    wb = load_workbook("excel3.xlsx")
                    ws = wb.active
                    
                    if len(n1) != 0 and len(n2) != 0 and len(n3) != 0:
                      if len(n1) > 1:
                         lb.append(str(arr[0][0]))
                         z0 = str(math.floor((arr[0][len(n1)-1] + arr[0][len(n1)])/2))
                         lb.append(z0)
                      else:
                         lb.append(str(arr[0][0]))
                         z0 = (str(arr[0][len(n1)-1]))
                         lb.append(z0)
                      if len(n2) > 1:
                         z1 = str(arr[0][len(n1)]) + ' - ' + z0
                         lb.append(z1)
                         z2 = str(math.floor((arr[0][len(n2)] + arr[0][len(n1) + len(n2)])/2)) + ' - ' + z0
                         lb.append(z2)
                         z3 = str(arr[0][len(n1) + len(n2)]) + ' - ' + str(math.floor((arr[0][len(n2)] + arr[0][len(n1) + len(n2)])/2))
                         lb.append(z3)
                         z4 = str(arr[0][-1]) + ' - ' + str(math.floor((arr[0][len(n2)] + arr[0][len(n1) + len(n2)])/2))
                         lb.append(z4)
                      else:
                         z1 = str(arr[0][len(n1)]) + ' - ' + z0
                         lb.append(z1)
                         z2 = str(arr[0][len(n2)]) + ' - ' + z0
                         lb.append(z2)
                         z3 = str(arr[0][len(n1) + len(n2)]) + ' - ' + str(arr[0][len(n2)])
                         lb.append(z3)
                         z4 = str(arr[0][-1]) + ' - ' + str(arr[0][len(n2)])
                         lb.append(z4)

                    for i, row in enumerate(rows, o*num_of_CHPD):
                        for j, value in enumerate(row, 1):
                            cell = ws.cell(row=i, column=j)
                            cell.value = value
                        if i % num_of_CHPD != 0:
                              ws['D'+str(o*num_of_CHPD)].value = lb[0]
                              ws['D'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD)].value = lb[1]
                              ws['E'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 1)].value = lb[2]
                              ws['D'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 1)].value = lb[3]
                              ws['E'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD)].value = 1
                              ws['C'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 1)].value = 2
                              ws['C'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=double, left=thins, right=thins)
                        else:
                              ws['D'+str(o*num_of_CHPD + 2)].value = lb[4]
                              ws['D'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 2)].value = lb[5]
                              ws['E'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 2)].value = 3
                              ws['C'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=thins, left=thins, right=thins)
                    

                    ws.merge_cells('B'+str(o*num_of_CHPD)+':B' + str((o*num_of_CHPD)+2))
                    ws['B'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                    ws['B'+str(o*num_of_CHPD)].value = str(num_of_CHPD) +'.' + str(o)
                    o+=1
                    wb.save('excel3.xlsx')
                    print(n1)
                    print(n2)
                    print(n3)
                    print(lb)
                    
                    lb=[]
                    ub = []
                    n1 = []
                    n2 = []
                    n3 = []
                    n4 = []
                    n5 = []
# Out:
# ...
# 3. 1
# ['[0.3]']
# ['[0.5]']
# ['[0.8]', '[1.2]', '[3.1]', '[4.3]', '[5.2]', '[6.7]']
# ['1', '1', '4 - 1', '4 - 1', '8 - 4', '28 - 4']
# ...
# 3. 2
# ['[0.3]']
# ['[0.5]', '[0.8]']
# ['[1.2]', '[3.1]', '[4.3]', '[5.2]', '[6.7]']
# ['1', '1', '4 - 1', '9 - 1', '11 - 9', '28 - 9']
# ...
# 3. 3
# ['[0.3]']
# ['[0.5]', '[0.8]', '[1.2]']
# ['[3.1]', '[4.3]', '[5.2]', '[6.7]']
# ['1', '1', '4 - 1', '12 - 1', '13 - 12', '28 - 12']
# ...
# 3. 4
# ['[0.3]']
# ['[0.5]', '[0.8]', '[1.2]', '[3.1]']
# ['[4.3]', '[5.2]', '[6.7]']
# ['1', '1', '4 - 1', '14 - 1', '16 - 14', '28 - 14']
# ...
# 3. 5
# ['[0.3]']
# ['[0.5]', '[0.8]', '[1.2]', '[3.1]', '[4.3]']
# ['[5.2]', '[6.7]']
# ['1', '1', '4 - 1', '18 - 1', '20 - 18', '28 - 18']
# ...
# 3. 6
# ['[0.3]']
# ['[0.5]', '[0.8]', '[1.2]', '[3.1]', '[4.3]', '[5.2]']
# ['[6.7]']
# ['1', '1', '4 - 1', '24 - 1', '28 - 24', '28 - 24']
# ...
# 3. 7
# ['[0.3]', '[0.5]']
# ['[0.8]']
# ['[1.2]', '[3.1]', '[4.3]', '[5.2]', '[6.7]']
# ['1', '6', '8 - 6', '4 - 6', '11 - 4', '28 - 4']
# ...
# 3. 8
# ...

# %%
o=1
num_of_CHPD = 4
for p1 in range(1,len(arr[0])):
     for p2 in range(p1+1, len(arr[0])):
          for p3 in range(p2 + 1, len(arr[0])):
                    print('_______')
                    for i in range (0,p1):
                         z="[" + str(arr[1][i]) + "]"
                         n1.append(z)
                    for i in range (p1,p2):
                         z="[" + str(arr[1][i]) + "]"
                         n2.append(z)
                    for i in range(p2, p3):
                         z="[" + str(arr[1][i]) + "]"
                         n3.append(z)
                    for i in range(p3,len(arr[0])):
                         z="[" + str(arr[1][i]) + "]"
                         n4.append(z)
                    for a in n1:
                         for b in n2:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n2:
                         for b in n3:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n3:
                         for b in n4:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    print("4.",o)
                    full_data1 = 'v'.join(n1)
                    full_data2 = 'v'.join(n2)
                    full_data3 = 'v'.join(n3)
                    full_data4 = 'v'.join(n4)
                    columns = ['ЗДП', 'А', '№ Периода', 'НГ', 'ВГ']
                    rows = [
                        [full_data1],
                        [full_data2],
                        [full_data3],
                        [full_data4]
                    ]

                    wb = load_workbook("excel4.xlsx")
                    ws = wb.active

                    if len(n1)!=0 and len(n4)!=0 and len(n3)!=0 and len(n2)!=0:
                      if len(n1) > 1:
                        lb.append(str(arr[0][0]))
                        z0 = str(math.floor((arr[0][len(n1)-1] + arr[0][len(n1)])/2))
                        lb.append(z0)
                      else:  
                        lb.append(str(arr[0][0]))
                        z0 = str(arr[0][len(n1) - 1])
                        lb.append(z0)
                      if len(n2) > 1:
                        z1 = str(arr[0][len(n1)])
                        z1_1 = z1  + ' - ' + z0
                        lb.append(z1_1)
                        z2 = str(math.floor((arr[0][len(n2)] + arr[0][len(n1) + len(n2)])/2))
                        z2_1 = z2  + ' - ' + z0
                        lb.append(z2_1)
                      else:
                        z1 = str(arr[0][len(n1)])
                        z1_1 = z1  + ' - ' + z0
                        lb.append(z1_1)
                        z2 = str(arr[0][len(n2)])
                        z2_1 = z2  + ' - ' + z0
                        lb.append(z2_1)
                      if len(n3) > 1:
                        z3 = str(arr[0][len(n1) + len(n2)])
                        z3_1 = z3  + ' - ' + z2
                        lb.append(z3_1)
                        z4 = str(math.floor((arr[0][len(n1) + len(n2) + len(n3) - 1] + arr[0][len(n1) + len(n2) + len(n3)])/2))
                        z4_1 = z4 + ' - ' + z2
                        lb.append(z4_1)
                      else:
                        z3 = str(arr[0][len(n1) + len(n2)])
                        z3_1 = z3  + ' - ' + z2
                        lb.append(z3_1)
                        z4 = str(arr[0][len(n1) + len(n2) + len(n3) - 1])
                        z4_1 = z4 + ' - ' + z2
                        lb.append(z4_1)

                      z5 = str(arr[0][len(n1) + len(n2) + len(n3)]) + ' - ' + z4
                      lb.append(z5)
                      z6 = str(arr[0][-1]) + ' - ' + z4
                      lb.append(z6)
                      print(len(lb),'lenlennene')
                    
                    for i, row in enumerate(rows, o*num_of_CHPD):
                        for j, value in enumerate(row, 1):
                            cell = ws.cell(row=i, column=j)
                            cell.value = value
                            print(i,',',i % num_of_CHPD,',',num_of_CHPD)
                        if i % num_of_CHPD != 3:
                              ws['D'+str(o*num_of_CHPD)].value = lb[0]
                              ws['D'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD)].value = lb[1]
                              ws['E'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 1)].value = lb[2]
                              ws['D'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 1)].value = lb[3]
                              ws['E'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 2)].value = lb[4]
                              ws['D'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 2)].value = lb[5]
                              ws['E'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD)].value = 1
                              ws['C'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 1)].value = 2
                              ws['C'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 2)].value = 3
                              ws['C'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=thins, left=thins, right=thins)
                        else:
                              ws['D'+str(o*num_of_CHPD + 3)].value = lb[6]
                              ws['D'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 3)].value = lb[7]
                              ws['E'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 3)].value = 4
                              ws['C'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=double, left=thins, right=thins)

                    ws.merge_cells('B'+str(o*num_of_CHPD)+':B' + str((o*num_of_CHPD)+3))
                    ws['B'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                    ws['B'+str(o*num_of_CHPD)].value = str(num_of_CHPD) +'.' + str(o)
                    wb.save('excel4.xlsx')

                    o+=1
                    lb=[]
                    ub = []
                    n1 = []
                    n2 = []
                    n3 = []
                    n4 = []
                    n5 = []

# %%
o = 1
num_of_CHPD = 5
for p1 in range(1,len(arr[0])):
     for p2 in range(p1+1, len(arr[0])):
          for p3 in range(p2 + 1, len(arr[0])):
               for p4 in range(p3 + 1, len(arr[0])):
                    for i in range (0,p1):
                         z="[" + str(arr[1][i]) + "]"
                         n1.append(z)
                    for i in range (p1,p2):
                         z="[" + str(arr[1][i]) + "]"
                         n2.append(z)
                    for i in range(p2, p3):
                         z="[" + str(arr[1][i]) + "]"
                         n3.append(z)
                    for i in range(p3,p4):
                         z="[" + str(arr[1][i]) + "]"
                         n4.append(z)
                    for i in range(p4, len(arr[0])):
                         z="[" + str(arr[1][i]) + "]"
                         n5.append(z)
                    for a in n1:
                         for b in n2:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n2:
                         for b in n3:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n3:
                         for b in n4:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    for a in n4:
                         for b in n5:
                              if a==b:
                                   n1 = []
                                   n2 = []
                                   n3 = []
                                   n4 = []
                                   n5 = []
                    print("5.",o)
                    full_data1 = 'v'.join(n1)
                    full_data2 = 'v'.join(n2)
                    full_data3 = 'v'.join(n3)
                    full_data4 = 'v'.join(n4)
                    full_data5 = 'v'.join(n5)
                    columns = ['ЗДП', 'А', '№ Периода', 'НГ', 'ВГ']
                    rows = [
                        [full_data1],
                        [full_data2],
                        [full_data3],
                        [full_data4],
                        [full_data5]
                    ]

                    wb = load_workbook("excel5.xlsx")
                    ws = wb.active
                    #print(len(n1) + len(n2) + len(n3))

                    if len(n1)!=0 and len(n5)!=0 and len(n4)!=0 and len(n3)!=0 and len(n2)!=0:
                      if len(n1) > 1:
                        lb.append(str(arr[0][0]))
                        z0 = str(math.floor((arr[0][len(n1)-1] + arr[0][len(n1)])/2))
                        lb.append(z0)
                      else:
                        lb.append(str(arr[0][0]))
                        z0 = str(arr[0][len(n1)-1])
                        lb.append(z0)
                      if len(n2) > 1:
                        z1 = str(arr[0][len(n1)])
                        z1_1 = z1  + ' - ' + z0
                        lb.append(z1_1)
                        z2 = str(math.floor((arr[0][len(n2)] + arr[0][len(n1) + len(n2)])/2))
                        z2_1 = z2  + ' - ' + z0
                        lb.append(z2_1)
                      else:
                        z1 = str(arr[0][len(n1)])
                        z1_1 = z1  + ' - ' + z0
                        lb.append(z1_1)
                        z2 = str(arr[0][len(n1) + len(n2) - 1])
                        z2_1 = z2  + ' - ' + z0
                        lb.append(z2_1)
                      if len(n3) > 1:
                        z3 = str(arr[0][len(n1) + len(n2)])
                        z3_1 = z3  + ' - ' + z2
                        lb.append(z3_1)
                        z4 = str(math.floor((arr[0][len(n1) + len(n2) + len(n3) - 1] + arr[0][len(n1) + len(n2) + len(n3)])/2))
                        z4_1 = z4 + ' - ' + z2
                        lb.append(z4_1)
                      else:
                        z3 = str(arr[0][len(n1) + len(n2)])
                        z3_1 = z3  + ' - ' + z2
                        lb.append(z3_1)
                        z4 = str(arr[0][len(n1) + len(n2) + len(n3) - 1])
                        z4_1 = z4 + ' - ' + z2
                        lb.append(z4_1)
                      if len(n4) > 1:
                        z5 = str(arr[0][len(n1) + len(n2) + len(n3) ])
                        z5_1 = z5 + ' - ' + z4
                        lb.append(z5_1)
                        z6 = str(math.floor((arr[0][len(n1) + len(n2) + len(n3) + len(n4)-1] + arr[0][len(n1) + len(n2) + len(n3) + len(n4)])/2))
                        z6_1 = z6 + ' - ' + z4
                        lb.append(z6_1)
                      else:
                        z5 = str(arr[0][len(n1) + len(n2) + len(n3) ])
                        z5_1 = z5 + ' - ' + z4
                        lb.append(z5_1)
                        z6 = str(arr[0][len(n1) + len(n2) + len(n3) + len(n4)-1])
                        z6_1 = z6 + ' - ' + z4
                        lb.append(z6_1)

                      z7 = str(arr[0][len(n1) + len(n2) + len(n3) + len(n4)])
                      z7_1 = z7 + ' - ' + z6
                      lb.append(z7_1)
                      z8 = str(arr[0][-1])
                      z8_1 = z8 + ' - ' + z6
                      lb.append(z8_1)

                      for i, row in enumerate(rows, o*num_of_CHPD):
                        for j, value in enumerate(row, 1):
                            cell = ws.cell(row=i, column=j)
                            cell.value = value
                            print(i,',',i % num_of_CHPD,',',num_of_CHPD)
                        if i % num_of_CHPD != 4:
                              ws['D'+str(o*num_of_CHPD)].value = lb[0]
                              ws['D'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD)].value = lb[1]
                              ws['E'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 1)].value = lb[2]
                              ws['D'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 1)].value = lb[3]
                              ws['E'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 2)].value = lb[4]
                              ws['D'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 2)].value = lb[5]
                              ws['E'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['D'+str(o*num_of_CHPD + 3)].value = lb[6]
                              ws['D'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 3)].value = lb[7]
                              ws['E'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD)].value = 1
                              ws['C'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 1)].value = 2
                              ws['C'+str(o*num_of_CHPD + 1)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 2)].value = 3
                              ws['C'+str(o*num_of_CHPD + 2)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 3)].value = 4
                              ws['C'+str(o*num_of_CHPD + 3)].border = Border(top=thins, bottom=thins, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=thins, left=thins, right=thins)
                        else:
                              ws['D'+str(o*num_of_CHPD + 4)].value = lb[8]
                              ws['D'+str(o*num_of_CHPD + 4)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['E'+str(o*num_of_CHPD + 4)].value = lb[9]
                              ws['E'+str(o*num_of_CHPD + 4)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              ws['C'+str(o*num_of_CHPD + 4)].value = 5
                              ws['C'+str(o*num_of_CHPD + 4)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                              cell.border = Border(top=thins, bottom=double, left=thins, right=thins)

                    ws.merge_cells('B'+str(o*num_of_CHPD)+':B' + str((o*num_of_CHPD)+4))
                    ws['B'+str(o*num_of_CHPD)].border = Border(top=thins, bottom=double, left=thins, right=thins)
                    ws['B'+str(o*num_of_CHPD)].value = str(num_of_CHPD) +'.' + str(o)
                    wb.save('excel5.xlsx')
                    print(lb)
                    o+=1
                    lb=[]
                    ub = []
                    n1 = []
                    n2 = []
                    n3 = []
                    n4 = []
                    n5 = []
# Out:
# 5. 1
# 5 , 0 , 5
# 6 , 1 , 5
# 7 , 2 , 5
# 8 , 3 , 5
# 9 , 4 , 5
# ['1', '1', '4 - 1', '4 - 1', '8 - 4', '8 - 4', '11 - 8', '11 - 8', '13 - 11', '28 - 11']
# 5. 2
# 10 , 0 , 5
# 11 , 1 , 5
# 12 , 2 , 5
# 13 , 3 , 5
# 14 , 4 , 5
# ['1', '1', '4 - 1', '4 - 1', '8 - 4', '8 - 4', '11 - 8', '14 - 8', '16 - 14', '28 - 14']
# 5. 3
# 15 , 0 , 5
# 16 , 1 , 5
# 17 , 2 , 5
# 18 , 3 , 5
# 19 , 4 , 5
# ['1', '1', '4 - 1', '4 - 1', '8 - 4', '8 - 4', '11 - 8', '18 - 8', '20 - 18', '28 - 18']
# 5. 4
# 20 , 0 , 5
# 21 , 1 , 5
# 22 , 2 , 5
# 23 , 3 , 5
# 24 , 4 , 5
# ['1', '1', '4 - 1', '4 - 1', '8 - 4', '8 - 4', '11 - 8', '24 - 8', '28 - 24', '28 - 24']
# 5. 5
# 25 , 0 , 5
# 26 , 1 , 5
# 27 , 2 , 5
# 28 , 3 , 5
# 29 , 4 , 5
# ['1', '1', '4 - 1', '4 - 1', '8 - 4', '12 - 4', '13 - 12', '13 - 12', '16 - 13', '28 - 13']
# 5. 6
# 30 , 0 , 5
# 31 , 1 , 5
# 32 , 2 , 5
# 33 , 3 , 5
# 34 , 4 , 5
# ['1', '1', '4 - 1', '4 - 1', '8 - 4', '12 - 4', '13 - 12', '18 - 12', '20 - 18', '28 - 18']
# 5. 7
# 35 , 0 , 5
# ...
